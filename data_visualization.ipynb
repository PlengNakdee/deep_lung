# %%
import matplotlib.pyplot as plt
import cv2
import random
import os
import pandas as pd
from glob import glob

# %%
images = glob(os.path.join('/Users/plengmac/Desktop/Lung/patch/', '*.png'))
images[0:10]
# Out:
# ['/Users/plengmac/Desktop/Lung/patch/1.3.6.1.4.1.14519.5.2.1.6279.6001.171667800241622018839592854574.png',
#  '/Users/plengmac/Desktop/Lung/patch/1.3.6.1.4.1.14519.5.2.1.6279.6001.178680586845223339579041794709.png',
#  '/Users/plengmac/Desktop/Lung/patch/1.3.6.1.4.1.14519.5.2.1.6279.6001.216526102138308489357443843021.png',
#  '/Users/plengmac/Desktop/Lung/patch/1.3.6.1.4.1.14519.5.2.1.6279.6001.122914038048856168343065566972.png',
#  '/Users/plengmac/Desktop/Lung/patch/1.3.6.1.4.1.14519.5.2.1.6279.6001.979083010707182900091062408058.png',
#  '/Users/plengmac/Desktop/Lung/patch/1.3.6.1.4.1.14519.5.2.1.6279.6001.140527383975300992150799777603.png',
#  '/Users/plengmac/Desktop/Lung/patch/1.3.6.1.4.1.14519.5.2.1.6279.6001.163931625580639955914619627409.png',
#  '/Users/plengmac/Desktop/Lung/patch/1.3.6.1.4.1.14519.5.2.1.6279.6001.315214756157389122376518747372.png',
#  '/Users/plengmac/Desktop/Lung/patch/1.3.6.1.4.1.14519.5.2.1.6279.6001.144438612068946916340281098509.png',
# ...

# %%
# visualize data
dir = '/Users/plengmac/Desktop/Lung/patch/1.3.6.1.4.1.14519.5.2.1.6279.6001.202811684116768680758082619196.png'
img = cv2.imread(dir)
plt.imshow(img)
img.shape
# Out:
# (64, 64, 3)

# %%
r = random.sample(images, 3)

# Matplotlib black magic
plt.figure(figsize=(16,16))
plt.subplot(131) # onr row, 3 column
plt.imshow(cv2.imread(r[0]))

plt.subplot(132)
plt.imshow(cv2.imread(r[1]))

plt.subplot(133)
plt.imshow(cv2.imread(r[2]));

# %%
df = pd.read_csv('/Users/plengmac/Desktop/Lung/candidates_no_cord.csv')
df.head()
# Out:
#                                            seriesuid  class
# 0  1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...      1
# 1  1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...      0
# 2  1.3.6.1.4.1.14519.5.2.1.6279.6001.100332161840...      0
# 3  1.3.6.1.4.1.14519.5.2.1.6279.6001.100398138793...      1
# 4  1.3.6.1.4.1.14519.5.2.1.6279.6001.100398138793...      0

# %%
df['class'].value_counts()
# Out:
# 0    888
# 1    590
# Name: class, dtype: int64
